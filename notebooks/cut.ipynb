# %% [markdown]
# <a href="https://colab.research.google.com/github/Mateus929/painter-gan/blob/main/notebooks/cut.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# This section contains setup code specific to running the notebook on Google Colab. This code depends on the environment and may need to be adjusted based on your specific setup.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')
user_name = userdata.get('GITHUB_USERNAME')
mail = userdata.get('GITHUB_MAIL')

# !git config --global user.name "{user_name}"
# !git config --global user.email "{mail}"
# !git clone https://{token}@github.com/Mateus929/painter-gan.git

# %cd painter-gan

# %%
# %%capture
from google.colab import userdata
kaggle_json_path = userdata.get('KAGGLE_JSON_PATH')
wandb_api_login = userdata.get('WANDB_API_LOGIN')
! ./scripts/download_data.sh -f {kaggle_json_path}
! ./scripts/setup.sh {wandb_api_login}

# %% [markdown]
# # MAIN

# %%
cut_config_ultralight = {
    # Run settings
    "run_name": "cut-monet-ultralight",
    "resume_training": False,

    "val_ratio": 0.1,
    "image_size": 256,
    "batch_size": 1,

    # Model architecture - MINIMAL
    "num_residual_blocks": 4,  # 9 -> 4 (minimal for basic quality)
    "num_downsampling": 2,

    # Contrastive learning settings - MINIMAL
    "nce_layers": [0, 4],  # Only 2 layers (early + late)
    "nce_dim": 64,  # 256 -> 64 (very light projection)
    "num_patches": 64,  # 256 -> 64 (minimal patch sampling)
    "nce_temperature": 0.07,
    "use_mlp": False,
    "lambda_NCE": 1.0,
    "lambda_identity": 0.0,

    "num_epochs": 10,
    "lr": 0.0002,
    "save_every": 1,

    "cosine_threshold": 0.5,
}


import training.train_cut
training.train_cut.train_cut(cut_config_ultralight)
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch/d_loss</td><td>█▃▃▃▃▁▂▃▃▃▂▄▂▂▁▂▂▃▄▂▂▄▂▃▂▃▅▃▂▂▃▄▃▃▃▂▃▂▁▁</td></tr><tr><td>batch/g_loss</td><td>█▄▅▄▃▂▁▄▂▂▂▁▂▂▂▁▂▂▃▂▂▂▂▂▂▁▁▂▁▂▂▂▃▂▃▂▁▁▄▂</td></tr><tr><td>batch/gan_loss</td><td>▄█▃▁▃▂▄▁▁▁▁▂▂▁▂▂▂▂▄▂▃▃▂▃▂▂▁▃▂▄▂▂▃▅▃▂▃▂▂▃</td></tr><tr><td>batch/idt_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch/nce_loss</td><td>█▇▆▄▅▄▂▄▂▂▂▂▃▂▂▁▁▃▂▁▂▃▃▂▂▂▂▂▁▂▁▂▁▁▁▂▃▃▁▂</td></tr><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch/d_loss</td><td>0.10863</td></tr><tr><td>batch/g_loss</td><td>0.38368</td></tr><tr><td>batch/gan_loss</td><td>0.33896</td></tr><tr><td>batch/idt_loss</td><td>0</td></tr><tr><td>batch/nce_loss</td><td>0.04473</td></tr><tr><td>epoch</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cut-monet-ultralight</strong> at: <a href='https://wandb.ai/MLBeasts/monet-cut/runs/bea48e00' target="_blank">https://wandb.ai/MLBeasts/monet-cut/runs/bea48e00</a><br> View project at: <a href='https://wandb.ai/MLBeasts/monet-cut' target="_blank">https://wandb.ai/MLBeasts/monet-cut</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251221_112457-bea48e00/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/painter-gan/wandb/run-20251221_113839-26120a8b</code>
# Syncing run <strong><a href='https://wandb.ai/MLBeasts/monet-cut/runs/26120a8b' target="_blank">cut-monet-ultralight</a></strong> to <a href='https://wandb.ai/MLBeasts/monet-cut' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLBeasts/monet-cut' target="_blank">https://wandb.ai/MLBeasts/monet-cut</a>
#  View run at <a href='https://wandb.ai/MLBeasts/monet-cut/runs/26120a8b' target="_blank">https://wandb.ai/MLBeasts/monet-cut/runs/26120a8b</a>
# Using device: cuda
#
# Starting training for 10 epochs...
#
# Epoch [1/10] | Train G: 0.6167, D: 0.2513, NCE: 0.2769 || Val NCE: 0.1946
# Epoch [2/10] | Train G: 0.4510, D: 0.2455, NCE: 0.1313 || Val NCE: 0.0775
# Epoch [3/10] | Train G: 0.4411, D: 0.2409, NCE: 0.1127 || Val NCE: 0.0987
# Epoch [4/10] | Train G: 0.4413, D: 0.2375, NCE: 0.1065 || Val NCE: 0.0976
# Epoch [5/10] | Train G: 0.4344, D: 0.2366, NCE: 0.0980 || Val NCE: 0.0908
# Epoch [6/10] | Train G: 0.4356, D: 0.2350, NCE: 0.0968 || Val NCE: 0.0889
# Epoch [7/10] | Train G: 0.4094, D: 0.2395, NCE: 0.0883 || Val NCE: 0.0825
# Epoch [8/10] | Train G: 0.4530, D: 0.2281, NCE: 0.0976 || Val NCE: 0.1093
# Epoch [9/10] | Train G: 0.5324, D: 0.2071, NCE: 0.1145 || Val NCE: 0.1470
# Epoch [10/10] | Train G: 0.6328, D: 0.1784, NCE: 0.1278 || Val NCE: 0.1122
#
# ================================================================================
# 🔍 Running final MiFID evaluation
# ================================================================================
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:00<00:00, 180MB/s]
# Generating images: 100%|██████████| 22/22 [00:08<00:00,  2.50it/s]
# Extracting features: 100%|██████████| 22/22 [00:02<00:00,  7.41it/s]
# Extracting features: 100%|██████████| 1/1 [00:00<00:00,  3.06it/s]
# FID:   212.1354
# dThr:  0.3132
# MiFID: 677.4209
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch/d_loss</td><td>▆▃▄▇█▁▆▅█▂▆▆▄▆▄▄█▄▇▃▄▁▇▇▆▄▅▃▅▅▄▄▄▃▇▃▃▃▃▂</td></tr><tr><td>batch/g_loss</td><td>▅▆▄▂▂▅▄▄▃▃▂█▂▂▂▃▃▂▁▂▂▁▂▆▂▅▂▃▂▅▂▅▂▂▄▄▁▄▅▅</td></tr><tr><td>batch/gan_loss</td><td>▆▆█▃▆▁▅█▄▃▄▄█▃▆▂▄▃▂▆▆▄▁▄▆▄▄▃▅▄▁▂▄▇▃▄▆▃▅▇</td></tr><tr><td>batch/idt_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch/nce_loss</td><td>▃▂▁▃▂▂▂▂▃▂▁▂▁▂▂▁▂▁▂▁▁▂█▁▁▃▁▁▁▃▂▂▃▁▁▁▁▂▄▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▃▃▄▄▅▅▆▆▆▆▆▆▆▆▆▆▆▆▇▇█████</td></tr><tr><td>final/FID</td><td>▁</td></tr><tr><td>final/MiFID</td><td>▁</td></tr><tr><td>final/dThr</td><td>▁</td></tr><tr><td>train/d_loss</td><td>█▇▇▇▇▆▇▆▄▁</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch/d_loss</td><td>0.11776</td></tr><tr><td>batch/g_loss</td><td>0.95157</td></tr><tr><td>batch/gan_loss</td><td>0.75568</td></tr><tr><td>batch/idt_loss</td><td>0</td></tr><tr><td>batch/nce_loss</td><td>0.19589</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>final/FID</td><td>212.13539</td></tr><tr><td>final/MiFID</td><td>677.42087</td></tr><tr><td>final/dThr</td><td>0.31315</td></tr><tr><td>train/d_loss</td><td>0.17844</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cut-monet-ultralight</strong> at: <a href='https://wandb.ai/MLBeasts/monet-cut/runs/26120a8b' target="_blank">https://wandb.ai/MLBeasts/monet-cut/runs/26120a8b</a><br> View project at: <a href='https://wandb.ai/MLBeasts/monet-cut' target="_blank">https://wandb.ai/MLBeasts/monet-cut</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251221_113839-26120a8b/logs</code>

# %%
cut_config_light = {
    # Run settings
    "run_name": "cut-monet-light",
    "resume_training": False,
    "verbose": 1,

    "val_ratio": 0.3,
    "image_size": 256,
    "batch_size": 1,

    "num_residual_blocks": 6,
    "num_downsampling": 2,

    "nce_layers": [0, 5, 8],
    "nce_dim": 128,
    "num_patches": 128,
    "nce_temperature": 0.07,
    "use_mlp": True,

    "lambda_NCE": 1.0,
    "lambda_identity": 0.0,

    "num_epochs": 150,
    "lr": 0.0002,
    "save_every": 1,

    "cosine_threshold": 0.5,
}

import training.train_cut
training.train_cut.train_cut(cut_config_light)
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/painter-gan/wandb/run-20251221_135722-702ce973</code>
# Syncing run <strong><a href='https://wandb.ai/MLBeasts/monet-cut/runs/702ce973' target="_blank">cut-monet-ultralight</a></strong> to <a href='https://wandb.ai/MLBeasts/monet-cut' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLBeasts/monet-cut' target="_blank">https://wandb.ai/MLBeasts/monet-cut</a>
#  View run at <a href='https://wandb.ai/MLBeasts/monet-cut/runs/702ce973' target="_blank">https://wandb.ai/MLBeasts/monet-cut/runs/702ce973</a>
# Using device: cuda
#
# Starting training for 10 epochs...
#
# Epoch [1/10] | Train G: 0.6341, D: 0.2501, NCE: 0.2964 || Val NCE: 0.1735
# Epoch [2/10] | Train G: 0.4717, D: 0.2424, NCE: 0.1415 || Val NCE: 0.1189
# Epoch [3/10] | Train G: 0.4658, D: 0.2369, NCE: 0.1239 || Val NCE: 0.1285
# Epoch [4/10] | Train G: 0.4513, D: 0.2362, NCE: 0.1100 || Val NCE: 0.1198
# Epoch [5/10] | Train G: 0.4393, D: 0.2368, NCE: 0.1035 || Val NCE: 0.1154
# Epoch [6/10] | Train G: 0.4277, D: 0.2389, NCE: 0.1008 || Val NCE: 0.0928
# Epoch [7/10] | Train G: 0.4461, D: 0.2329, NCE: 0.1051 || Val NCE: 0.1051
# Epoch [8/10] | Train G: 0.5129, D: 0.2143, NCE: 0.1190 || Val NCE: 0.1209
# Epoch [9/10] | Train G: 0.6209, D: 0.1853, NCE: 0.1380 || Val NCE: 0.2133
# Epoch [10/10] | Train G: 0.7130, D: 0.1587, NCE: 0.1488 || Val NCE: 0.2070
#
# ================================================================================
# 🔍 Running final MiFID evaluation
# ================================================================================
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Generating images: 100%|██████████| 22/22 [00:08<00:00,  2.54it/s]
# Extracting features: 100%|██████████| 22/22 [00:02<00:00,  7.45it/s]
# Extracting features: 100%|██████████| 1/1 [00:00<00:00,  3.04it/s]
# FID:   240.3849
# dThr:  0.3372
# MiFID: 712.9464
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch/d_loss</td><td>▄▆▂█▅▅▄▂▅▅▃▃▃▃▆▅▄▂▃▁▅▃▄▄▄▄▃▂▂▁▂▅▃▂▁▃▃▂▂▂</td></tr><tr><td>batch/g_loss</td><td>▄▆▃▇▂▆▃▃▃▃▄▃▃▃▆▄▃▂▃▄▆▃█▁▂▃▂▃▃▂▄▄▃▄▂▅▅▄▅▄</td></tr><tr><td>batch/gan_loss</td><td>▂▃▃▂▃▂▂▂▃▂▂▃▃▂▄▂▃▂▃▁▃▄▃▂▂▅▃▂▃▃▃▂▃▃▄▂▆▅█▃</td></tr><tr><td>batch/idt_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch/nce_loss</td><td>▂▁▆▂▁▃▄▃▃▁▅▁▂▁▇▂▁▁▁▂▃▁▂█▂▂▂▆▁▁▁▂▄▂█▃▂▄▂▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▃▃▃▃▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇█</td></tr><tr><td>final/FID</td><td>▁</td></tr><tr><td>final/MiFID</td><td>▁</td></tr><tr><td>final/dThr</td><td>▁</td></tr><tr><td>train/d_loss</td><td>█▇▇▇▇▇▇▅▃▁</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch/d_loss</td><td>0.1549</td></tr><tr><td>batch/g_loss</td><td>0.677</td></tr><tr><td>batch/gan_loss</td><td>0.65868</td></tr><tr><td>batch/idt_loss</td><td>0</td></tr><tr><td>batch/nce_loss</td><td>0.01832</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>final/FID</td><td>240.38489</td></tr><tr><td>final/MiFID</td><td>712.94642</td></tr><tr><td>final/dThr</td><td>0.33717</td></tr><tr><td>train/d_loss</td><td>0.15871</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cut-monet-ultralight</strong> at: <a href='https://wandb.ai/MLBeasts/monet-cut/runs/702ce973' target="_blank">https://wandb.ai/MLBeasts/monet-cut/runs/702ce973</a><br> View project at: <a href='https://wandb.ai/MLBeasts/monet-cut' target="_blank">https://wandb.ai/MLBeasts/monet-cut</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251221_135722-702ce973/logs</code>

# %%
cut_config_light = {
    # Run settings
    "run_name": "cut-monet-light",
    "resume_training": False,
    "verbose": 1,

    "val_ratio": 0.3,
    "image_size": 256,
    "batch_size": 1,

    "num_residual_blocks": 6,
    "num_downsampling": 2,

    "nce_layers": [0, 5, 8],
    "nce_dim": 128,
    "num_patches": 128,
    "nce_temperature": 0.07,
    "use_mlp": True,

    "lambda_NCE": 1.0,
    "lambda_identity": 0.0,

    "num_epochs": 10,
    "lr": 0.0002,
    "save_every": 1,

    "cosine_threshold": 0.5,
}

import training.train_cut
training.train_cut.train_cut(cut_config_light)
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch/d_loss</td><td>▁</td></tr><tr><td>batch/g_loss</td><td>▁</td></tr><tr><td>batch/gan_loss</td><td>▁</td></tr><tr><td>batch/idt_loss</td><td>▁</td></tr><tr><td>batch/nce_loss</td><td>▁</td></tr><tr><td>epoch</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch/d_loss</td><td>0.54413</td></tr><tr><td>batch/g_loss</td><td>6.16822</td></tr><tr><td>batch/gan_loss</td><td>0.94649</td></tr><tr><td>batch/idt_loss</td><td>0</td></tr><tr><td>batch/nce_loss</td><td>5.22173</td></tr><tr><td>epoch</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cut-monet-light</strong> at: <a href='https://wandb.ai/MLBeasts/monet-cut/runs/cde33189' target="_blank">https://wandb.ai/MLBeasts/monet-cut/runs/cde33189</a><br> View project at: <a href='https://wandb.ai/MLBeasts/monet-cut' target="_blank">https://wandb.ai/MLBeasts/monet-cut</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251221_162051-cde33189/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/painter-gan/wandb/run-20251221_162125-7148acdd</code>
# Syncing run <strong><a href='https://wandb.ai/MLBeasts/monet-cut/runs/7148acdd' target="_blank">cut-monet-light</a></strong> to <a href='https://wandb.ai/MLBeasts/monet-cut' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLBeasts/monet-cut' target="_blank">https://wandb.ai/MLBeasts/monet-cut</a>
#  View run at <a href='https://wandb.ai/MLBeasts/monet-cut/runs/7148acdd' target="_blank">https://wandb.ai/MLBeasts/monet-cut/runs/7148acdd</a>
# Using device: cuda
#
# Starting training for 10 epochs...

# %%
cut_config_optimal = {
    "run_name": "cut-monet-optimal",
    "resume_training": False,
    "verbose": 2,
    "val_ratio": 0.3,
    "image_size": 256,
    "batch_size": 1,

    "num_residual_blocks": 9,  # Standard depth, proven quality
    "num_downsampling": 2,  # Standard for 256x256

    "nce_layers": [0, 4, 8, 12],  # 4 layers - sweet spot
    "nce_dim": 256,  # Standard projection dimension
    "num_patches": 256,  # Standard patch sampling
    "nce_temperature": 0.07,
    "use_mlp": True,
    "lambda_NCE": 1.0,
    "lambda_identity": 0.0,
    "num_epochs": 10,
    "lr": 0.0002,
    "save_every": 1,
    "cosine_threshold": 0.5,
}

import training.train_cut
training.train_cut.train_cut(cut_config_optimal)
