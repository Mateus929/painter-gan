# %% [markdown]
# <a href="https://colab.research.google.com/github/Mateus929/painter-gan/blob/main/notebooks/gan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# This section contains setup code specific to running the notebook on Google Colab. This code depends on the environment and may need to be adjusted based on your specific setup.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')
user_name = userdata.get('GITHUB_USERNAME')
mail = userdata.get('GITHUB_MAIL')

# !git config --global user.name "{user_name}"
# !git config --global user.email "{mail}"
# !git clone https://{token}@github.com/Mateus929/painter-gan.git

# %cd painter-gan

# %%
# %%capture
from google.colab import userdata
kaggle_json_path = userdata.get('KAGGLE_JSON_PATH')
wandb_api_login = userdata.get('WANDB_API_LOGIN')
! ./scripts/download_data.sh -f {kaggle_json_path}
! ./scripts/setup.sh {wandb_api_login}

# %% [markdown]
# # CycleGan Low Quality Images

# %%
MONET_JPG_SAMPLE_PATH = "data/monet_jpg/000c1e3bff.jpg"
PHOTO_JPG_SAMPLE_PATH = "data/photo_jpg/00068bc07f.jpg"

from PIL import Image

monet_img = Image.open(MONET_JPG_SAMPLE_PATH)
photo_img = Image.open(PHOTO_JPG_SAMPLE_PATH)

print("Monet Mode: ", monet_img.mode,)        # RGB, RGBA, L, CMYK, etc.
print("Photo Mode: ", photo_img.mode,)        # RGB, RGBA, L, CMYK, etc.

print("Monet Size:", monet_img.size)          # (width, height)
print("Photo Size:", photo_img.size)          # (width, height)
# Out:
# Monet Mode:  RGB
# Photo Mode:  RGB
# Monet Size: (256, 256)
# Photo Size: (256, 256)

# %%
config = {
    'num_residual_blocks': 6,      # Lighter model
    'lr': 0.0002,
    'batch_size': 4,                # Small batch for speed
    'image_size': 128,              # Smaller images for faster training
    'lambda_cycle': 10.0,
    'lambda_identity': 5.0,
    'num_epochs': 10,               # Short run
    'save_every': 5,
    'resume_training': False,       # Fresh start
    'run_name' : "sample_run"
}

# Start training
from training.train_cyclegan import train_cyclegan
train_cyclegan(config)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Currently logged in as: zhorzholianimate (MLBeasts) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/painter-gan/wandb/run-20251211_123721-497e4fdc</code>
# Syncing run <strong><a href='https://wandb.ai/MLBeasts/monet-cyclegan/runs/497e4fdc' target="_blank">sample_run</a></strong> to <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">https://wandb.ai/MLBeasts/monet-cyclegan</a>
# ...

# %%
config = {
    'num_residual_blocks': 6,      # Lighter model
    'lr': 0.0002,
    'batch_size': 1,                # Small batch for speed
    'image_size': 128,              # Smaller images for faster training
    'lambda_cycle': 10.0,
    'lambda_identity': 5.0,
    'num_epochs': 50,               # Short run
    'save_every': 5,
    'eval_every': 25,
    'resume_training': False,       # Fresh start
    'run_name' : "base_run"
}

# Start training
from training.train_cyclegan import train_cyclegan
train_cyclegan(config)
# Out:
# Finishing previous runs because reinit is set to 'default'.
# ...

# %%
config = {
    'num_residual_blocks': 6,      # Lighter model
    'lr': 0.0002,
    'batch_size': 1,                # Small batch for speed
    'image_size': 128,              # Smaller images for faster training
    'lambda_cycle': 10.0,
    'lambda_identity': 5.0,
    'num_epochs': 30,               # Short run
    'save_every': 5,
    'eval_every': 30,
    'resume_training': True,
    'run_name' : "base_run",
    'run_id': '19b7ed35'
}

# Start training
from training.train_cyclegan import train_cyclegan
train_cyclegan(config)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Currently logged in as: zhorzholianimate (MLBeasts) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/painter-gan/wandb/run-20251214_101141-19b7ed35</code>
# Resuming run <strong><a href='https://wandb.ai/MLBeasts/monet-cyclegan/runs/19b7ed35' target="_blank">base_run</a></strong> to <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">https://wandb.ai/MLBeasts/monet-cyclegan</a>
#  View run at <a href='https://wandb.ai/MLBeasts/monet-cyclegan/runs/19b7ed35' target="_blank">https://wandb.ai/MLBeasts/monet-cyclegan/runs/19b7ed35</a>
# ...

# %%
config = {
    'num_residual_blocks': 6,
    'lr': 0.0002,
    'batch_size': 2,
    'image_size': 128,

    'lambda_cycle': 5.0,
    'lambda_identity': 0.0,

    'num_epochs': 30,
    'save_every': 3,
    'eval_every': 30,

    'resume_training': False,
    'run_name': "mifid_safe_run"
}


from training.train_cyclegan import train_cyclegan
train_cyclegan(config)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Currently logged in as: zhorzholianimate (MLBeasts) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/painter-gan/wandb/run-20251215_083630-8989d233</code>
# Syncing run <strong><a href='https://wandb.ai/MLBeasts/monet-cyclegan/runs/8989d233' target="_blank">mifid_safe_run</a></strong> to <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">https://wandb.ai/MLBeasts/monet-cyclegan</a>
# ...

# %% [markdown]
# # CycleGan High Quality Images

# %%
config = {
    'num_residual_blocks': 9,        # High-res capacity
    'lr': 0.0003,                    # Slightly higher LR for faster learning
    'batch_size': 1,                 # High-res batch
    'image_size': 256,

    'lambda_cycle': 3.0,             # Weakened cycle to avoid memorization
    'lambda_identity': 0.0,          # No identity loss for fresh start

    'num_epochs': 10,                # Short run
    'save_every': 1,
    'eval_every': 10,                 # Frequent evaluation for short run

    'resume_training': True,        # Fresh start
    'run_name': "256px_fast_run",
    'run_id': 'ec3916b3'
}

from training.train_cyclegan import train_cyclegan
train_cyclegan(config)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Currently logged in as: zhorzholianimate (MLBeasts) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/painter-gan/wandb/run-20251219_080200-ec3916b3</code>
# Resuming run <strong><a href='https://wandb.ai/MLBeasts/monet-cyclegan/runs/ec3916b3' target="_blank">256px_fast_run</a></strong> to <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">https://wandb.ai/MLBeasts/monet-cyclegan</a>
# ...

# %%
config = {
    'num_residual_blocks': 3,      # Lighter model
    'lr': 1e-4,
    'batch_size': 2,                # Small batch for speed
    'image_size': 64,              # Smaller images for faster training
    'lambda_cycle': 10.0,
    'lambda_identity': 5.0,
    'num_epochs': 2,               # Short run
    'save_every': 1,
    'resume_training': False,       # Fresh start
    'run_name' : "test_run",
    'verbose' : 1
}


import training.train_cyclegan_random
training.train_cyclegan_random.train_cyclegan(config)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Currently logged in as: zhorzholianimate (MLBeasts) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/painter-gan/wandb/run-20251220_170421-2c415937</code>
# Syncing run <strong><a href='https://wandb.ai/MLBeasts/monet-cyclegan/runs/2c415937' target="_blank">test_run</a></strong> to <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">https://wandb.ai/MLBeasts/monet-cyclegan</a>
#  View run at <a href='https://wandb.ai/MLBeasts/monet-cyclegan/runs/2c415937' target="_blank">https://wandb.ai/MLBeasts/monet-cyclegan/runs/2c415937</a>
# ...

# %%
config = {
    "num_residual_blocks": 9,     # number of residual blocks in the generator
    "lr": 2e-4,
    "batch_size": 4,
    "num_epochs": 5,
    "image_size": 256,

    "lambda_cycle": 10.0,
    "lambda_identity": 5.0,

    "cosine_threshold": 0.5,

    "save_every": 1,
    "resume_training": False,

    "run_name": "random_bacth_cyclegan_256_ptx",
    "verbose": 1,
}


import training.train_cyclegan_random
training.train_cyclegan_random.train_cyclegan(config)
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/painter-gan/wandb/run-20251220_171351-99d1241b</code>
# Syncing run <strong><a href='https://wandb.ai/MLBeasts/monet-cyclegan/runs/99d1241b' target="_blank">random_bacth_cyclegan_256_ptx</a></strong> to <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">https://wandb.ai/MLBeasts/monet-cyclegan</a>
#  View run at <a href='https://wandb.ai/MLBeasts/monet-cyclegan/runs/99d1241b' target="_blank">https://wandb.ai/MLBeasts/monet-cyclegan/runs/99d1241b</a>
# Using device: cuda
#
# Starting training for 5 epochs...
#
# Epoch [1/5] | Train G: 7.6447, D: 0.3830, Cycle: 4.5465 || Val Cycle: 3.8868, Val Id: 1.7999
# Epoch [2/5] | Train G: 6.4599, D: 0.3016, Cycle: 3.5397 || Val Cycle: 3.5065, Val Id: 1.5075
# ...

# %%
config = {
    "num_residual_blocks": 9,     # number of residual blocks in the generator
    "lr": 2e-4,
    "batch_size": 4,
    "num_epochs": 25,
    "image_size": 256,

    "lambda_cycle": 10.0,
    "lambda_identity": 5.0,

    "cosine_threshold": 0.5,

    "save_every": 1,
    "resume_training": True,

    "run_name": "random_bacth_cyclegan_256_ptx",
    "verbose": 1,
    "run_id" : "99d1241b"
}


import training.train_cyclegan_random
training.train_cyclegan_random.train_cyclegan(config)
# Out:
# Finishing previous runs because reinit is set to 'default'.
# ...

# %%
config = {
    "num_residual_blocks": 9,     # number of residual blocks in the generator
    "lr": 2e-4,
    "batch_size": 4,
    "num_epochs": 30,
    "image_size": 256,

    "lambda_cycle": 10.0,
    "lambda_identity": 5.0,

    "cosine_threshold": 0.5,

    "save_every": 1,
    "resume_training": True,

    "run_name": "random_bacth_cyclegan_256_ptx",
    "verbose": 1,
    "run_id" : "99d1241b"
}


import training.train_cyclegan_random
training.train_cyclegan_random.train_cyclegan(config)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Currently logged in as: zhorzholianimate (MLBeasts) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/painter-gan/wandb/run-20251223_093809-99d1241b</code>
# Resuming run <strong><a href='https://wandb.ai/MLBeasts/monet-cyclegan/runs/99d1241b' target="_blank">random_bacth_cyclegan_256_ptx</a></strong> to <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">https://wandb.ai/MLBeasts/monet-cyclegan</a>
# ...

# %%
config = {
    "num_residual_blocks": 9,     # number of residual blocks in the generator
    "lr": 2e-4,
    "batch_size": 1,
    "num_epochs": 5,
    "image_size": 256,

    "lambda_cycle": 5.0,
    "lambda_identity": 0.0,

    "cosine_threshold": 0.5,

    "save_every": 1,
    "resume_training": False,

    "run_name": "random_bacth_cyclegan_256_ptx_low_mem",
    "verbose": 1,
}


import training.train_cyclegan_random
training.train_cyclegan_random.train_cyclegan(config)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Currently logged in as: zhorzholianimate (MLBeasts) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/painter-gan/wandb/run-20251223_161248-6b0195ad</code>
# Syncing run <strong><a href='https://wandb.ai/MLBeasts/monet-cyclegan/runs/6b0195ad' target="_blank">random_bacth_cyclegan_256_ptx_low_mem</a></strong> to <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">https://wandb.ai/MLBeasts/monet-cyclegan</a>
# ...

# %%
config = {
    "num_residual_blocks": 9,     # number of residual blocks in the generator
    "lr": 2e-4,
    "batch_size": 1,
    "num_epochs": 10,
    "image_size": 256,

    "lambda_cycle": 5.0,
    "lambda_identity": 0.0,

    "cosine_threshold": 0.5,

    "save_every": 1,
    "resume_training": True,
    "run_id": "6b0195ad",

    "run_name": "random_bacth_cyclegan_256_ptx_low_mem",
    "verbose": 1,
}


import training.train_cyclegan_random
training.train_cyclegan_random.train_cyclegan(config)
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/painter-gan/wandb/run-20251226_073112-6b0195ad</code>
# Resuming run <strong><a href='https://wandb.ai/MLBeasts/monet-cyclegan/runs/6b0195ad' target="_blank">random_bacth_cyclegan_256_ptx_low_mem</a></strong> to <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">https://wandb.ai/MLBeasts/monet-cyclegan</a>
#  View run at <a href='https://wandb.ai/MLBeasts/monet-cyclegan/runs/6b0195ad' target="_blank">https://wandb.ai/MLBeasts/monet-cyclegan/runs/6b0195ad</a>
# Using device: cuda
# Resuming from checkpoint: /content/drive/MyDrive/paint-gan-checkpoints/6b0195ad/checkpoint_epoch_4.pth
# Resuming from epoch 5
#
# Starting training for 5 epochs...
#
# ...

# %%
config = {
    "num_residual_blocks": 9,     # number of residual blocks in the generator
    "lr": 2e-4,
    "batch_size": 1,
    "num_epochs": 25,
    "image_size": 256,

    "lambda_cycle": 5.0,
    "lambda_identity": 0.0,

    "cosine_threshold": 0.5,

    "save_every": 1,
    "resume_training": True,
    "run_id": "6b0195ad",

    "run_name": "random_bacth_cyclegan_256_ptx_low_mem",
    "verbose": 1,
}


import training.train_cyclegan_random
training.train_cyclegan_random.train_cyclegan(config)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Currently logged in as: zhorzholianimate (MLBeasts) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/painter-gan/wandb/run-20251227_155457-6b0195ad</code>
# Resuming run <strong><a href='https://wandb.ai/MLBeasts/monet-cyclegan/runs/6b0195ad' target="_blank">random_bacth_cyclegan_256_ptx_low_mem</a></strong> to <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLBeasts/monet-cyclegan' target="_blank">https://wandb.ai/MLBeasts/monet-cyclegan</a>
# ...
